# %%
import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
df = pd.read_csv('supermarket_sales.csv')
df = df.loc[:, ['City','Customer type','Gender','Product line', 'Quantity']]
df.head()
# Out:
#         City Customer type  Gender            Product line  Quantity
# 0     Yangon        Member  Female       Health and beauty         7
# 1  Naypyitaw        Normal  Female  Electronic accessories         5
# 2     Yangon        Normal    Male      Home and lifestyle         7
# 3     Yangon        Member    Male       Health and beauty         8
# 4     Yangon        Normal    Male       Sports and travel         7

# %%
data = list(df['Product line'])
data[:3]
# Out:
# ['Health and beauty', 'Electronic accessories', 'Home and lifestyle']

# %%
te = TransactionEncoder()
te_data = te.fit(data).transform(data)
df = pd.DataFrame(te_data,columns=te.columns_)
df.head()
# Out:
#              E      F      H      S     a      b      c      d     e  ...  \
# 0  True  False  False   True  False  True   True  False   True  True  ...
# 1  True   True  False  False  False  True  False   True  False  True  ...
# 2  True  False  False   True  False  True  False  False   True  True  ...
# 3  True  False  False   True  False  True   True  False   True  True  ...
# 4  True  False  False  False   True  True  False  False   True  True  ...
#
#        m     n      o      p      r      s     t      u      v      y
# 0  False  True  False  False  False  False  True   True  False   True
# 1  False  True   True  False   True   True  True  False  False  False
# 2   True  True   True  False  False   True  True  False  False   True
# 3  False  True  False  False  False  False  True   True  False   True
# 4  False  True   True   True   True   True  True  False   True  False
#
# [5 rows x 25 columns]

# %%
frequent_itemset = apriori(df, min_support=0.5, use_colnames=True)
frequent_itemset
# Out:
#      support               itemsets
# 0      1.000                    ( )
# 1      1.000                    (a)
# 2      0.652                    (d)
# 3      1.000                    (e)
# 4      0.508                    (i)
# ..       ...                    ...
# 298    0.508     (e, o, s, i, a, n)
# 299    0.688     (e, o, r, s, a, n)
# 300    0.500  (d, e, o, s, a,  , n)
# 301    0.508  (e, o, s, i, a,  , n)
# 302    0.688  (e, o, r, s, a,  , n)
#
# [303 rows x 2 columns]

# %%
rules = association_rules(frequent_itemset, metric="lift", min_threshold=1)
rules
# Out:
#      antecedents         consequents  antecedent support  consequent support  \
# 0            (a)                 ( )               1.000               1.000
# 1            ( )                 (a)               1.000               1.000
# 2            (d)                 ( )               0.652               1.000
# 3            ( )                 (d)               1.000               0.652
# 4            ( )                 (e)               1.000               1.000
# ...          ...                 ...                 ...                 ...
# 4653         (r)  (e, o, s, a,  , n)               0.688               0.848
# 4654         (s)  (e, o, r, a,  , n)               0.848               0.688
# 4655         (a)  (e, o, r, s,  , n)               1.000               0.688
# 4656         ( )  (e, o, r, s, a, n)               1.000               0.688
# 4657         (n)  (e, o, r, s, a,  )               1.000               0.688
#
#       support  confidence      lift  leverage  conviction
# 0       1.000    1.000000  1.000000  0.000000         inf
# 1       1.000    1.000000  1.000000  0.000000         inf
# 2       0.652    1.000000  1.000000  0.000000         inf
# 3       0.652    0.652000  1.000000  0.000000      1.0000
# 4       1.000    1.000000  1.000000  0.000000         inf
# ...       ...         ...       ...       ...         ...
# 4653    0.688    1.000000  1.179245  0.104576         inf
# 4654    0.688    0.811321  1.179245  0.104576      1.6536
# 4655    0.688    0.688000  1.000000  0.000000      1.0000
# 4656    0.688    0.688000  1.000000  0.000000      1.0000
# 4657    0.688    0.688000  1.000000  0.000000      1.0000
#
# [4658 rows x 9 columns]
